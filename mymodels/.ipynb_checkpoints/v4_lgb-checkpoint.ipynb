# %%
import ccf2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import gc
import warnings
import lightgbm as lgb
import xgboost
from sklearn.model_selection import KFold,StratifiedKFold,train_test_split,cross_validate
from sklearn.metrics import mean_squared_error as mse
from sklearn.grid_search import GridSearchCV
warnings.filterwarnings('ignore')

path = '../input/'
# Out:
# D:\programfiles\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\programfiles\anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# # load data

# %%
data = ccf2.loaddata(path)

# %%
data.head()
# Out:
#    adcode  bodyType  id  model province  regMonth  regYear  popularity  \
# 0  310000         0   0      0       上海         1     2016      1479.0
# 1  530000         0   0      0       云南         1     2016      1594.0
# 2  150000         0   0      0      内蒙古         1     2016      1479.0
# 3  110000         0   0      0       北京         1     2016      2370.0
# 4  510000         0   0      0       四川         1     2016      3562.0
#
#    carCommentVolum  newsReplyVolum  label  mt  log_label  log_popularity
# 0             11.0           106.0  292.0   1   5.676754        7.299121
# 1             11.0           106.0  466.0   1   6.144186        7.374002
# 2             11.0           106.0  257.0   1   5.549076        7.299121
# 3             11.0           106.0  408.0   1   6.011267        7.770645
# 4             11.0           106.0  610.0   1   6.413459        8.178077

# %%
data.describe()
# Out:
#               adcode      bodyType            id         model      regMonth  \
# count   36960.000000  36960.000000  36960.000000  36960.000000  36960.000000
# mean   347727.272727      0.766667    382.452381     29.500000      5.928571
# std    136281.363156      0.803476   1104.799221     17.318337      3.514595
# min    110000.000000      0.000000      0.000000      0.000000      1.000000
# 25%    230000.000000      0.000000      0.000000     14.750000      3.000000
# 50%    355000.000000      1.000000      0.000000     29.500000      5.500000
# 75%    440000.000000      1.000000      0.000000     44.250000      9.000000
# max    610000.000000      3.000000   5368.000000     59.000000     12.000000
#
#             regYear     popularity  carCommentVolum  newsReplyVolum  \
# count  36960.000000   31680.000000     31680.000000    31680.000000
# mean    2016.714286    2311.965941       250.479167     1989.809722
# std        0.699864    2980.547086       318.648963     2324.517694
# min     2016.000000      25.000000         0.000000        0.000000
# 25%     2016.000000     700.000000        54.000000      335.000000
# 50%     2017.000000    1445.500000       149.500000     1432.500000
# 75%     2017.000000    2816.000000       307.000000     2712.000000
# max     2018.000000  116300.000000      2834.000000    20770.000000
#
#               label            mt     log_label  log_popularity
# count  31680.000000  36960.000000  31680.000000    31680.000000
# mean     608.709122     14.500000      5.880215        7.240776
# std      779.076734      8.077856      1.059051        1.025449
# min        2.000000      1.000000      0.693147        3.218876
# 25%      182.000000      7.750000      5.204007        6.551080
# 50%      363.000000     14.500000      5.894403        7.276211
# 75%      737.000000     21.250000      6.602588        7.943073
# max    15317.000000     28.000000      9.636719       11.663928

# %%
import math
# data['model_weight'] = data.groupby('model')['label'].transform('mean') 
# data['n_label'] = data['label'] / data['model_weight'] 
data['log_label'] = data['label'].apply(lambda x: math.log(x))
data['log_popularity'] = data['popularity'].apply(lambda x: math.log(x))
data['log_carCommentVolum'] = data['carCommentVolum'].apply(lambda x: math.log(x+1))
data['log_newsReplyVolum'] = data['newsReplyVolum'].apply(lambda x: math.log(x+1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-560de0a342e6> in <module>()
#       4 data['log_label'] = data['label'].apply(lambda x: math.log(x))
#       5 data['log_popularity'] = data['popularity'].apply(lambda x: math.log(x))
# ----> 6 data['log_carCommentVolum'] = data['carCommentVolum'].apply(lambda x: math.log(x))
#       7 data['log_newsReplyVolum'] = data['newsReplyVolum'].apply(lambda x: math.log(x))
#
# D:\programfiles\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-4-560de0a342e6> in <lambda>(x)
#       4 data['log_label'] = data['label'].apply(lambda x: math.log(x))
#       5 data['log_popularity'] = data['popularity'].apply(lambda x: math.log(x))
# ----> 6 data['log_carCommentVolum'] = data['carCommentVolum'].apply(lambda x: math.log(x))
#       7 data['log_newsReplyVolum'] = data['newsReplyVolum'].apply(lambda x: math.log(x))
#
# ValueError: math domain error

# %% [markdown]
# # feature

# %% [markdown]
# ## 构建特征

# %% [markdown]
# ### 平移12特征

# %%
data,shift_feat = ccf2.genShitFeat(data,[12])

# %% [markdown]
# ### 分组特征

# %%
target=['popularity','carCommentVolum','newsReplyVolum','label']
fea_list = ['adcode','bodyType','model','regMonth']
data,stat_feat = ccf2.genStatFeat(data,fea_list,target)
# Out:
# 统计列的sum,mean,max,min,分位数0.2,分位数0.5,分位数0.8
# 构造特征: adcode
# 构造特征: adcode _ popularity
# 构造特征: adcode _ carCommentVolum
# 构造特征: adcode _ newsReplyVolum
# 构造特征: adcode _ label
# 构造特征: bodyType
# 构造特征: bodyType _ popularity
# 构造特征: bodyType _ carCommentVolum
# 构造特征: bodyType _ newsReplyVolum
# 构造特征: bodyType _ label
# 构造特征: model
# 构造特征: model _ popularity
# 构造特征: model _ carCommentVolum
# 构造特征: model _ newsReplyVolum
# 构造特征: model _ label
# 构造特征: regMonth
# 构造特征: regMonth _ popularity
# 构造特征: regMonth _ carCommentVolum
# 构造特征: regMonth _ newsReplyVolum
# 构造特征: regMonth _ label

# %%
data.tail()
# Out:
#        adcode  bodyType    id  model province  regMonth  regYear  popularity  \
# 36955  350000         0  5364     59       福建         4     2018         NaN
# 36956  210000         0  5365     59       辽宁         4     2018         NaN
# 36957  500000         0  5366     59       重庆         4     2018         NaN
# 36958  610000         0  5367     59       陕西         4     2018         NaN
# 36959  230000         0  5368     59      黑龙江         4     2018         NaN
#
#        carCommentVolum  newsReplyVolum           ...            \
# 36955              NaN             NaN           ...
# 36956              NaN             NaN           ...
# 36957              NaN             NaN           ...
# 36958              NaN             NaN           ...
# 36959              NaN             NaN           ...
#
#        newsReplyVolum_regMonth_median2  newsReplyVolum_regMonth_median5  \
# 36955                            137.0                            316.0
# 36956                            137.0                            316.0
# 36957                            137.0                            316.0
# 36958                            137.0                            316.0
# 36959                            137.0                            316.0
#
#        newsReplyVolum_regMonth_median8  label_regMonth_sum  \
# 36955                            722.2           1348827.0
# 36956                            722.2           1348827.0
# 36957                            722.2           1348827.0
# 36958                            722.2           1348827.0
# 36959                            722.2           1348827.0
#
#        label_regMonth_mean  label_regMonth_max  label_regMonth_mim  \
# 36955           510.919318              8733.0                11.0
# 36956           510.919318              8733.0                11.0
# 36957           510.919318              8733.0                11.0
# 36958           510.919318              8733.0                11.0
# 36959           510.919318              8733.0                11.0
#
#        label_regMonth_median2  label_regMonth_median5  label_regMonth_median8
# 36955                   137.0                   316.0                   722.2
# 36956                   137.0                   316.0                   722.2
# 36957                   137.0                   316.0                   722.2
# 36958                   137.0                   316.0                   722.2
# 36959                   137.0                   316.0                   722.2
#
# [5 rows x 128 columns]

# %%
cate_feat = ['adcode', 'bodyType', 'model', 'regMonth']
num_feat = ['regYear'] + shift_feat
features = num_feat+stat_feat

# %%
features = list(set(features))

# %%
stat_feat
# Out:
# ['adcode',
#  'popularity_adcode_sum',
#  'popularity_adcode_mean',
#  'popularity_adcode_max',
#  'popularity_adcode_mim',
#  'popularity_adcode_median2',
#  'popularity_adcode_median5',
#  'popularity_adcode_median8',
#  'adcode',
#  'carCommentVolum_adcode_sum',
#  'carCommentVolum_adcode_mean',
#  'carCommentVolum_adcode_max',
#  'carCommentVolum_adcode_mim',
#  'carCommentVolum_adcode_median2',
#  'carCommentVolum_adcode_median5',
#  'carCommentVolum_adcode_median8',
#  'adcode',
#  'newsReplyVolum_adcode_sum',
#  'newsReplyVolum_adcode_mean',
#  'newsReplyVolum_adcode_max',
#  'newsReplyVolum_adcode_mim',
#  'newsReplyVolum_adcode_median2',
#  'newsReplyVolum_adcode_median5',
#  'newsReplyVolum_adcode_median8',
#  'adcode',
#  'label_adcode_sum',
#  'label_adcode_mean',
#  'label_adcode_max',
#  'label_adcode_mim',
#  'label_adcode_median2',
#  'label_adcode_median5',
#  'label_adcode_median8',
#  'bodyType',
#  'popularity_bodyType_sum',
#  'popularity_bodyType_mean',
#  'popularity_bodyType_max',
#  'popularity_bodyType_mim',
#  'popularity_bodyType_median2',
#  'popularity_bodyType_median5',
#  'popularity_bodyType_median8',
#  'bodyType',
#  'carCommentVolum_bodyType_sum',
#  'carCommentVolum_bodyType_mean',
#  'carCommentVolum_bodyType_max',
#  'carCommentVolum_bodyType_mim',
#  'carCommentVolum_bodyType_median2',
#  'carCommentVolum_bodyType_median5',
#  'carCommentVolum_bodyType_median8',
#  'bodyType',
#  'newsReplyVolum_bodyType_sum',
#  'newsReplyVolum_bodyType_mean',
#  'newsReplyVolum_bodyType_max',
#  'newsReplyVolum_bodyType_mim',
#  'newsReplyVolum_bodyType_median2',
#  'newsReplyVolum_bodyType_median5',
#  'newsReplyVolum_bodyType_median8',
#  'bodyType',
#  'label_bodyType_sum',
#  'label_bodyType_mean',
#  'label_bodyType_max',
#  'label_bodyType_mim',
#  'label_bodyType_median2',
#  'label_bodyType_median5',
#  'label_bodyType_median8',
#  'model',
#  'popularity_model_sum',
#  'popularity_model_mean',
#  'popularity_model_max',
#  'popularity_model_mim',
#  'popularity_model_median2',
#  'popularity_model_median5',
#  'popularity_model_median8',
#  'model',
#  'carCommentVolum_model_sum',
#  'carCommentVolum_model_mean',
#  'carCommentVolum_model_max',
#  'carCommentVolum_model_mim',
#  'carCommentVolum_model_median2',
#  'carCommentVolum_model_median5',
#  'carCommentVolum_model_median8',
#  'model',
#  'newsReplyVolum_model_sum',
#  'newsReplyVolum_model_mean',
#  'newsReplyVolum_model_max',
#  'newsReplyVolum_model_mim',
#  'newsReplyVolum_model_median2',
#  'newsReplyVolum_model_median5',
#  'newsReplyVolum_model_median8',
#  'model',
#  'label_model_sum',
#  'label_model_mean',
#  'label_model_max',
#  'label_model_mim',
#  'label_model_median2',
#  'label_model_median5',
#  'label_model_median8',
#  'regMonth',
#  'popularity_regMonth_sum',
#  'popularity_regMonth_mean',
#  'popularity_regMonth_max',
#  'popularity_regMonth_mim',
#  'popularity_regMonth_median2',
#  'popularity_regMonth_median5',
#  'popularity_regMonth_median8',
#  'regMonth',
#  'carCommentVolum_regMonth_sum',
#  'carCommentVolum_regMonth_mean',
#  'carCommentVolum_regMonth_max',
#  'carCommentVolum_regMonth_mim',
#  'carCommentVolum_regMonth_median2',
#  'carCommentVolum_regMonth_median5',
#  'carCommentVolum_regMonth_median8',
#  'regMonth',
#  'newsReplyVolum_regMonth_sum',
#  'newsReplyVolum_regMonth_mean',
#  'newsReplyVolum_regMonth_max',
#  'newsReplyVolum_regMonth_mim',
#  'newsReplyVolum_regMonth_median2',
#  'newsReplyVolum_regMonth_median5',
#  'newsReplyVolum_regMonth_median8',
#  'regMonth',
#  'label_regMonth_sum',
#  'label_regMonth_mean',
#  'label_regMonth_max',
#  'label_regMonth_mim',
#  'label_regMonth_median2',
#  'label_regMonth_median5',
#  'label_regMonth_median8']

# %%
features
# Out:
# ['newsReplyVolum_bodyType_median8',
#  'popularity_regMonth_mim',
#  'carCommentVolum_adcode_mean',
#  'label_adcode_median5',
#  'newsReplyVolum_model_median5',
#  'label_regMonth_median2',
#  'carCommentVolum_model_median2',
#  'popularity_bodyType_sum',
#  'newsReplyVolum_model_median8',
#  'label_model_sum',
#  'carCommentVolum_adcode_max',
#  'newsReplyVolum_regMonth_median2',
#  'bodyType',
#  'popularity_adcode_median2',
#  'carCommentVolum_adcode_median5',
#  'newsReplyVolum_bodyType_mean',
#  'popularity_regMonth_median2',
#  'label_bodyType_median8',
#  'popularity_regMonth_mean',
#  'model',
#  'popularity_adcode_median5',
#  'newsReplyVolum_regMonth_median8',
#  'newsReplyVolum_regMonth_max',
#  'carCommentVolum_adcode_mim',
#  'newsReplyVolum_adcode_median2',
#  'label_bodyType_mean',
#  'label_bodyType_sum',
#  'popularity_regMonth_max',
#  'newsReplyVolum_adcode_median8',
#  'carCommentVolum_bodyType_median2',
#  'popularity_bodyType_median5',
#  'newsReplyVolum_bodyType_median2',
#  'label_regMonth_mean',
#  'popularity_adcode_mim',
#  'label_model_median2',
#  'popularity_model_mim',
#  'carCommentVolum_regMonth_mean',
#  'popularity_bodyType_mean',
#  'label_regMonth_sum',
#  'carCommentVolum_regMonth_median5',
#  'carCommentVolum_bodyType_sum',
#  'newsReplyVolum_adcode_mean',
#  'newsReplyVolum_adcode_sum',
#  'newsReplyVolum_regMonth_median5',
#  'carCommentVolum_bodyType_mim',
#  'label_model_median5',
#  'label_regMonth_max',
#  'label_adcode_mean',
#  'newsReplyVolum_model_max',
#  'carCommentVolum_bodyType_median5',
#  'popularity_model_max',
#  'popularity_bodyType_max',
#  'label_adcode_median2',
#  'label_model_median8',
#  'popularity_adcode_max',
#  'carCommentVolum_model_median8',
#  'carCommentVolum_bodyType_median8',
#  'carCommentVolum_model_max',
#  'carCommentVolum_model_mean',
#  'adcode',
#  'newsReplyVolum_adcode_median5',
#  'carCommentVolum_model_sum',
#  'popularity_bodyType_median2',
#  'newsReplyVolum_model_mim',
#  'newsReplyVolum_regMonth_mim',
#  'popularity_model_median5',
#  'newsReplyVolum_regMonth_sum',
#  'newsReplyVolum_regMonth_mean',
#  'newsReplyVolum_adcode_mim',
#  'popularity_model_median2',
#  'carCommentVolum_model_mim',
#  'carCommentVolum_adcode_median2',
#  'newsReplyVolum_bodyType_max',
#  'regYear',
#  'popularity_bodyType_mim',
#  'newsReplyVolum_model_median2',
#  'label_model_mim',
#  'popularity_regMonth_median8',
#  'label_regMonth_mim',
#  'label_regMonth_median5',
#  'carCommentVolum_regMonth_median8',
#  'popularity_adcode_mean',
#  'popularity_model_mean',
#  'carCommentVolum_regMonth_median2',
#  'label_model_max',
#  'newsReplyVolum_model_sum',
#  'carCommentVolum_adcode_sum',
#  'carCommentVolum_regMonth_sum',
#  'popularity_model_sum',
#  'shift_model_adcode_mt_label_12',
#  'carCommentVolum_bodyType_max',
#  'label_bodyType_median2',
#  'label_model_mean',
#  'carCommentVolum_adcode_median8',
#  'popularity_regMonth_sum',
#  'popularity_adcode_sum',
#  'popularity_adcode_median8',
#  'carCommentVolum_bodyType_mean',
#  'carCommentVolum_regMonth_mim',
#  'label_adcode_max',
#  'popularity_bodyType_median8',
#  'label_bodyType_median5',
#  'carCommentVolum_model_median5',
#  'newsReplyVolum_adcode_max',
#  'popularity_model_median8',
#  'label_regMonth_median8',
#  'newsReplyVolum_bodyType_median5',
#  'label_adcode_median8',
#  'newsReplyVolum_bodyType_sum',
#  'newsReplyVolum_model_mean',
#  'label_adcode_mim',
#  'carCommentVolum_regMonth_max',
#  'label_bodyType_max',
#  'newsReplyVolum_bodyType_mim',
#  'regMonth',
#  'popularity_regMonth_median5',
#  'label_adcode_sum',
#  'label_bodyType_mim']

# %% [markdown]
# # 构建模型

# %% [markdown]
# ## 拆分数据

# %%
train_idx = (data['mt'] <= 24)
test_idx = (data['mt'] > 24)

trainSet = data.loc[train_idx]
testSet = data.loc[test_idx]
# train_x = data[train_idx][features]
# train_y = data[train_idx]['n_label']
# train_y2 = data[train_idx]['label']
# valid_idx = (data['mt'].between(21, 24))
# valid_x = data[valid_idx][features]
# valid_y = data[valid_idx]['n_label']

# %%
trainSet.head()
# Out:
#    adcode  bodyType  id  model province  regMonth  regYear  popularity  \
# 0  310000         0   0      0       上海         1     2016      1479.0
# 1  530000         0   0      0       云南         1     2016      1594.0
# 2  150000         0   0      0      内蒙古         1     2016      1479.0
# 3  110000         0   0      0       北京         1     2016      2370.0
# 4  510000         0   0      0       四川         1     2016      3562.0
#
#    carCommentVolum  newsReplyVolum    ...      \
# 0             11.0           106.0    ...
# 1             11.0           106.0    ...
# 2             11.0           106.0    ...
# 3             11.0           106.0    ...
# 4             11.0           106.0    ...
#
#    newsReplyVolum_regMonth_median5  newsReplyVolum_regMonth_median8  \
# 0                            445.0                           1016.2
# 1                            445.0                           1016.2
# 2                            445.0                           1016.2
# 3                            445.0                           1016.2
# 4                            445.0                           1016.2
#
#    label_regMonth_sum  label_regMonth_mean  label_regMonth_max  \
# 0           1847111.0           699.663258              9433.0
# 1           1847111.0           699.663258              9433.0
# 2           1847111.0           699.663258              9433.0
# 3           1847111.0           699.663258              9433.0
# 4           1847111.0           699.663258              9433.0
#
#    label_regMonth_mim  label_regMonth_median2  label_regMonth_median5  \
# 0                 7.0                   190.0                   445.0
# 1                 7.0                   190.0                   445.0
# 2                 7.0                   190.0                   445.0
# 3                 7.0                   190.0                   445.0
# 4                 7.0                   190.0                   445.0
#
#    label_regMonth_median8  log_label
# 0                  1016.2   5.676754
# 1                  1016.2   6.144186
# 2                  1016.2   5.549076
# 3                  1016.2   6.011267
# 4                  1016.2   6.413459
#
# [5 rows x 129 columns]

# %% [markdown]
# ## cv 交叉验证

# %%
lgb_model = lgb.LGBMRegressor(
        num_leaves=32, reg_alpha=1, reg_lambda=0.1, objective='mse',
        max_depth=-1, learning_rate=0.05, min_child_samples=5, random_state=np.random.randint(1000),
        n_estimators=5000, subsample=0.8, colsample_bytree=0.8,
    )

# %%
# from sklearn.utils.multiclass import type_of_target
# type_of_target(train_y)
# Out:
# 'continuous'

# %%
kfd = KFold(n_splits=5,random_state=2020)
# res_prob = pd.DataFrame()
res = pd.DataFrame()

index = 1
for train_idx,test_idx in kfd.split(trainSet):
    print('-------------------','Kflod:',index,'------------------')
    
    lgb_model.fit(trainSet.loc[train_idx][features],trainSet.loc[train_idx]['log_label'], 
                  eval_set=[(trainSet.loc[train_idx][features],trainSet.loc[train_idx]['log_label']),
                            (trainSet.loc[test_idx][features],trainSet.loc[test_idx]['log_label'])],
                  categorical_feature=cate_feat, 
                  early_stopping_rounds=500,
                  verbose=100)
#     x_pred = lgb_model.predict(train_x[test_idx], num_iteration=lgb_model.best_iteration_)
    test_pred = lgb_model.predict(testSet[features], num_iteration=lgb_model.best_iteration_)
    res['prob_%s' % str(index)] = test_pred
    index = index+1
# Out:
# ------------------- Kflod: 1 ------------------
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's l2: 0.112269	valid_1's l2: 0.314704
# [200]	valid_0's l2: 0.0734337	valid_1's l2: 0.279116
# [300]	valid_0's l2: 0.056753	valid_1's l2: 0.257383
# [400]	valid_0's l2: 0.0478082	valid_1's l2: 0.248272
# [500]	valid_0's l2: 0.0422311	valid_1's l2: 0.241534
# [600]	valid_0's l2: 0.0341267	valid_1's l2: 0.166774
# [700]	valid_0's l2: 0.030301	valid_1's l2: 0.167115
# Early stopping, best iteration is:
# [261]	valid_0's l2: 0.0639623	valid_1's l2: 0.166658

# %%
res.head()
# Out:
#      prob_1    prob_2    prob_3    prob_4    prob_5
# 0  5.600725  5.608675  5.826002  5.643093  5.523109
# 1  6.066730  6.075514  6.183138  6.000402  5.925194
# 2  5.101544  5.103257  5.313150  5.082250  5.173730
# 3  5.957036  5.994856  6.024532  5.613954  6.001455
# 4  6.084311  6.093619  6.289394  6.031256  6.105834

# %%
sub = ccf2.genLogSub(data,res,5)

# %%
sub.to_csv(path+'sub/sub_cv4.csv',index=False,header=True)

# %%
df_imp = ccf2.featImport(lgb_model,features)

# %%
df_imp
# Out:
#                              features  import
# 19                              model    2318
# 59                             adcode    1376
# 89     shift_model_adcode_mt_label_12     919
# 5              label_regMonth_median2     311
# 3                label_adcode_median5     259
# 4        newsReplyVolum_model_median5     195
# 114                          regMonth     142
# 33              popularity_adcode_mim     139
# 13          popularity_adcode_median2     126
# 84                    label_model_max     120
# 63           newsReplyVolum_model_mim     115
# 76                    label_model_mim     108
# 35               popularity_model_mim     103
# 28      newsReplyVolum_adcode_median8     101
# 110                  label_adcode_mim     101
# 73                            regYear     100
# 6       carCommentVolum_model_median2      89
# 50               popularity_model_max      88
# 54              popularity_adcode_max      82
# 57          carCommentVolum_model_max      77
# 99                   label_adcode_max      77
# 12                           bodyType      76
# 18           popularity_regMonth_mean      74
# 70          carCommentVolum_model_mim      73
# 11    newsReplyVolum_regMonth_median2      73
# 36      carCommentVolum_regMonth_mean      69
# 48           newsReplyVolum_model_max      67
# 85           newsReplyVolum_model_sum      62
# 8        newsReplyVolum_model_median8      55
# 58         carCommentVolum_model_mean      50
# ..                                ...     ...
# 112                label_bodyType_max       0
# 30        popularity_bodyType_median5       0
# 2         carCommentVolum_adcode_mean       0
# 115       popularity_regMonth_median5       0
# 31    newsReplyVolum_bodyType_median2       0
# 29   carCommentVolum_bodyType_median2       0
# 69           popularity_model_median2       0
# 26                 label_bodyType_sum       0
# 62        popularity_bodyType_median2       0
# 72        newsReplyVolum_bodyType_max       0
# 20          popularity_adcode_median5       0
# 74            popularity_bodyType_mim       0
# 68          newsReplyVolum_adcode_mim       0
# 65           popularity_model_median5       0
# 77        popularity_regMonth_median8       0
# 64        newsReplyVolum_regMonth_mim       0
# 79             label_regMonth_median5       0
# 80   carCommentVolum_regMonth_median8       0
# 60      newsReplyVolum_adcode_median5       0
# 51            popularity_bodyType_max       0
# 83   carCommentVolum_regMonth_median2       0
# 23         carCommentVolum_adcode_mim       0
# 56   carCommentVolum_bodyType_median8       0
# 86         carCommentVolum_adcode_sum       0
# 55      carCommentVolum_model_median8       0
# 25                label_bodyType_mean       0
# 10         carCommentVolum_adcode_max       0
# 90       carCommentVolum_bodyType_max       0
# 91             label_bodyType_median2       0
# 117                label_bodyType_mim       0
#
# [118 rows x 2 columns]
